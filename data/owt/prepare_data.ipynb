# %%
from pathlib import Path

import tiktoken

from kernels.data import encode, open_mmap

# %%
DATA_DIR = Path("...")
RAW_DIR = DATA_DIR / "raw"
OUT_DIR = DATA_DIR / "tokens"
OUT_DIR.mkdir(exist_ok=True)

# %%
encoder = tiktoken.get_encoding("gpt2")

# %%
encode(encoder, OUT_DIR / "owt_valid.uint16.bin", RAW_DIR / "owt_valid.txt")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 290M/290M [00:12<00:00, 23.2MB/s, output tokens=6.59e+7]

# %%
encode(encoder, OUT_DIR / "owt_train.uint16.bin", RAW_DIR / "owt_train.txt")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 11.9G/11.9G [07:25<00:00, 26.7MB/s, output tokens=2.7e+9]

# %%
data = open_mmap(OUT_DIR / "owt_valid.uint16.bin")

# %%
encoder.decode(data[:100])
# Out:
# 'LOUISVILLE, Ky. — A few unflattering reviews are to be expected with any hotel, particularly one whose rates start at $49 per night. But while complaints about shabby rooms and thin towels are common in the industry, ones like these, from TripAdvisor.com, are not: “It is a clean hotel but there are a lot of homeless people there.” “Run far far away!!!!! This is a homeless shelter, not a hotel!”'
